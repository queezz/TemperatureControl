# %%
from simple_pid import PID
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,50,300)
y = x**0.25*40

pid = PID(1, 0.1, 0.05, setpoint=100)

out = np.array([pid(i) for i in y])
plt.plot(x,y)
plt.plot(x,out)
